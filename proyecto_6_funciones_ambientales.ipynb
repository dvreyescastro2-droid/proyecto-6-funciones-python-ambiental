# %% [markdown]
# # Proyecto 6 – Funciones en Python 🌿
#
# Este proyecto analiza datos ambientales (pH, temperatura, turbidez)
# usando funciones en Python, estructuras de datos y pandas.
#
# ## Contenido
#
# - Clasificación de pH
# - Análisis de temperatura
# - Evaluación con pandas

# %%
def cuadrado(x):
    return x ** 2

for i in range(5):
    print("Cuadrado:", cuadrado(i))
